# %%
import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")#UBICACION DE DATOS
df.head(5) #LECTURA DE DATOS
import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")#UBICACION DE DATOS
df.tail(5)#LECTURA DE DATOS

df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})
print (df)

df.to_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")

import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")
df = df [['company','price']][df.price==df['price'].max()]# ENCUENTRA EL DATO MAS ALTO EN LA COLUMNA DE PRECIOS
df

import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")
car_Manufacturers = df.groupby('company')#BUSCA DE UN GRUPO EN ESPECIFICO
toyotaDf = car_Manufacturers.get_group('toyota')#RELACIONA LA PALABRA TOYOTA PARA IMPRIMIR LA LISTA
toyotaDf

import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")
df['company'].value_counts()#CUENTA CUANTOS VALORES HAY EN TOTAL

import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")#UBICACION EN LA CUAL BUSCAR LOS DATOS
car_Manufacturers = df.groupby('company')#BUSCA GRUPO EN ESPECIFICO
priceDf = car_Manufacturers['company','price'].max()#ENCUENTRA LA COMPAÑIA CON LOS PRECIOS MAS ALTOS 
priceDf

import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")
car_Manufacturers = df.groupby('company')
mileageDf = car_Manufacturers['company','average-mileage'].mean()#PROMEDIO DE MILLAGE POR MARCA
mileageDf

import pandas as pd
carsDf = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)#ORDENA EL ORDEN DE MUESTRA DE MAYOR 
carsDf.head(5)#PRIMEROS 5 MUESTRA

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}#ASIGNACION DE DATO A UNA VARIABLE
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}#ASIGNACION DE DATO A UNA VARIABLE

import pandas as pd

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)#DATO DE LA LISTA CON LOS DATOS INGRESADOS

japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
carsDf2 = pd.DataFrame.from_dict(japaneseCars)#DATO DE LA LISTA CON LOS DATOS INGRESADOS

carsDf = pd.concat([carsDf1, carsDf2], keys=["Germany", "Japan"])
carsDf

import pandas as pd

Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}#MUESTRA DATO DE VARIABLES(MARCAS)
carPriceDf = pd.DataFrame.from_dict(Car_Price)#DATO PRECIO

car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}#MUESTRA DATO DE VARIABLES(MARCAS)
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)#DATO POWER

carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
carsDf#MUESTRA EN COLUMNA LO ANTERIOR
