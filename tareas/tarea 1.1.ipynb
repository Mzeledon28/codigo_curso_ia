# %%
import pandas as pd #cambio de variable
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")#busca el archivo de datos en la computadora, hay que poner direccion exacta en la que se ubica.
profitList = df ['total_profit'].tolist()#llamar una lista de beneficios 
monthList  = df ['month_number'].tolist()#llamar una lista de los meses
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year') #muestra los beneficios de la lista del ultimo año
plt.xlabel('Month number')#llamma variable del dato para la grafica del mes
plt.ylabel('Profit in dollar')#llama variable del dato para la grafica de los beneficion en dolares
plt.xticks(monthList)#inserta variable del mes
plt.title('Company profit per month')#muestra titulo de la grafica
plt.yticks([100000, 200000, 300000, 400000, 500000])#inserta variable del dolar
plt.show()# mostrar 

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")#busca el archivo de datos en la computadora, hay que poner direccion exacta en la que se ubica.
profitList = df ['total_profit'].tolist()#llamar una lista de beneficios 
monthList  = df ['month_number'].tolist()#llamar una lista de los meses

plt.plot(monthList, profitList, label = 'Profit data of last year', 
      color='r', marker='o', markerfacecolor='k', #define color de linea
      linestyle='--', linewidth=3)#tipo de grafico con linea descontinua 
      
plt.xlabel('Month Number'))#llamma variable del dato para la grafica del mes
plt.ylabel('Profit in dollar')#llama variable del dato para la grafica de los beneficion en dolares
plt.legend(loc='lower right')# muestra la leyenda en lugar especifico
plt.title('Company Sales data of last year')#titulo
plt.xticks(monthList)#datos de la horizantal
plt.yticks([100000, 200000, 300000, 400000, 500000])#datos de la vertical
plt.show()# mostrar

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()#leer dato especifico de la lista
faceWashSalesData   = df ['facewash'].tolist()#leer dato especifico de la lista
toothPasteSalesData = df ['toothpaste'].tolist()#leer dato especifico de la lista
bathingsoapSalesData   = df ['bathingsoap'].tolist()#leer dato especifico de la lista
shampooSalesData   = df ['shampoo'].tolist()#leer dato especifico de la lista
moisturizerSalesData = df ['moisturizer'].tolist()#leer dato especifico de la lista

plt.plot(monthList, faceCremSalesData,   label = 'Face cream Sales Data', marker='o', linewidth=3)#mueastra los nombres en el cuadro junto con su color
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o', linewidth=3)#mueastra los nombres en el cuadro junto con su color
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)#mueastra los nombres en el cuadro junto con su color
plt.plot(monthList, bathingsoapSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)#mueastra los nombres en el cuadro junto con su color
plt.plot(monthList, shampooSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)#mueastra los nombres en el cuadro junto con su color
plt.plot(monthList, moisturizerSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)#mueastra los nombres en el cuadro junto con su color

plt.xlabel('Month Number')#pone este nombre a la linea horizontal
plt.ylabel('Sales units in number')#pone este nombre a la linea vertical
plt.legend(loc='upper left')#muestra el cuadro de texto arriba 
plt.xticks(monthList)# valores de referencia horizontales
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])# valores de referencia verticales
plt.title('Sales data')#titulo
plt.show()

import pandas as pd #redundancia en el cambio de variable
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()#dato de la lista 
toothPasteSalesData = df ['toothpaste'].tolist()#dato de la lista
plt.scatter(monthList, toothPasteSalesData, label = 'Tooth paste Sales data')# la disperción
plt.xlabel('Month Number')#nombre de datos horizontales
plt.ylabel('Number of units Sold')#nombre de datos verticales
plt.legend(loc='upper left')#lugar del cuadro
plt.title(' Tooth paste Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")#condicional de muestra en la grafica
plt.show()

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()#d lista
faceCremSalesData   = df ['facecream'].tolist()#d lista
faceWashSalesData   = df ['facewash'].tolist()#d lista

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream sales data', align='edge')
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'Face Wash sales data', align='edge')
plt.xlabel('Month Number')# comentario de la horizontal
plt.ylabel('Sales units in number')#comentario vertical
plt.legend(loc='upper left')# lugar del cuadro de texto
plt.title(' Sales data')#titulo

plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")#condicional de grafica
plt.title('Facewash and facecream sales data')
plt.show()

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
profitList = df ['total_profit'].tolist()
labels = ['low', 'average', 'Good', 'Best']
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(profitList, profit_range, label = 'Profit data')
plt.xlabel('profit range in dollar')#variables horizontales
plt.ylabel('Actual Profit in dollar')#variables verticales
plt.legend(loc='upper left')#lugar de cuadro
plt.xticks(profit_range)#rango de altura de las barras
plt.title('Profit data')#titulo
plt.show()

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()#dato

labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), 
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]#lectura de datos de variables
plt.axis("equal")#creacion de la grafica
plt.pie(salesData, labels=labels, autopct='%1.1f%%')#estadistica en circulo
plt.legend(loc='lower right')#lugar de texto
plt.title('Sales data')#titulo
plt.show()

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()#dato
bathingsoap   = df ['bathingsoap'].tolist()#dato
faceWashSalesData   = df ['facewash'].tolist()#dato

f, axarr = plt.subplots(2, sharex=True)#verificación de lugar de grafica
axarr[0].plot(monthList, bathingsoap, label = 'Bathingsoap Sales Data', color='k', marker='o', linewidth=3)#datos de colores y demas de la grafica
axarr[0].set_title('Sales data of  a Bathingsoap')#titulo
axarr[1].plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', color='r', marker='o', linewidth=3)#datos de colores y demas de la grafica
axarr[1].set_title('Sales data of  a facewash')#titulo

plt.xticks(monthList)#variables horizontales
plt.xlabel('Month Number')#nombre hori
plt.ylabel('Sales units in number')#nombre vertical
plt.show()#mostrar

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()#dato

faceCremSalesData   = df ['facecream'].tolist()#dato
faceWashSalesData   = df ['facewash'].tolist()#dato
toothPasteSalesData = df ['toothpaste'].tolist()#dato
bathingsoapSalesData   = df ['bathingsoap'].tolist()#dato
shampooSalesData   = df ['shampoo'].tolist()#dato
moisturizerSalesData = df ['moisturizer'].tolist()#dato

plt.plot([],[],color='m', label='face Cream', linewidth=5)#caracteristicas de cada linea 
plt.plot([],[],color='c', label='Face wash', linewidth=5)#caracteristicas de cada linea
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)#caracteristicas de cada linea
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)#caracteristicas de cada linea
plt.plot([],[],color='g', label='Shampoo', linewidth=5)#caracteristicas de cada linea
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)#caracteristicas de cada linea

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData, 
              colors=['m','c','r','k','g','y'])#colores de las variables en la leyenda

plt.xlabel('Month Number')# nombre horizontales
plt.ylabel('Sales unints in Number')#nombre verticales
plt.title('Alll product sales data using stack plot')#titulo de grafica
plt.legend(loc='upper left')#lugar de la leyenda
plt.show()#mostrar
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-58e329327920> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")#busca el archivo de datos en la computadora, hay que poner direccion exacta en la que se ubica.
#       5 profitList = df ['total_profit'].tolist()#llamar una lista de beneficios
#       6 monthList  = df ['month_number'].tolist()#llamar una lista de los meses
#
# ...
